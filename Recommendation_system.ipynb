# %% [markdown]
# Student Name: Manoj Chandra Machavolu<br>
# Student Number: 1008518506

# %%
#all spark imports
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
spark = SparkSession.builder.appName("Integer").getOrCreate()

# %% [markdown]
# **Part A Q1)**

# %%
integerRDD = spark.sparkContext.textFile("/FileStore/tables/integer_1.txt", 8)

# %%
integerRDD.collect()
# Out:
# Out[4]: ['45687',
#  '5463',
#  '34443',
#  '223',
#  '456',
#  '4667',
#  '234',
#  '9008',
#  '1234',
#  '2597',
#  '6253',
#  '10399',
#  '3312',
#  '2175',
#  '20087',
#  '6698',
#  '31512',
#  '618',
#  '11698',
#  '13969',
#  '6575',
#  '24846',
#  '1313',
#  '30977',
#  '20927',
#  '24771',
#  '20293',
#  '24210',
#  '26005',
#  '9680',
#  '15297',
#  '4099',
#  '29625',
#  '9374',
#  '7645',
#  '7660',
#  '7025',
#  '15755',
#  '927',
#  '22795',
#  '7948',
#  '29343',
#  '23398',
#  '5755',
#  '27339',
#  '19416',
#  '3686',
#  '21687',
#  '16513',
#  '32643',
#  '10047',
#  '11831',
#  '14036',
#  '11079',
#  '23852',
#  '11767',
#  '18502',
#  '28848',
#  '21754',
#  '4309',
#  '4104',
#  '4656',
#  '18641',
#  '20317',
#  '29760',
#  '8784',
#  '20048',
#  '26629',
#  '16134',
#  '15865',
#  '26432',
#  '22918',
#  '20931',
#  '15958',
#  '17856',
#  '13488',
#  '771',
#  '28089',
#  '15865',
#  '22489',
#  '5740',
#  '12871',
#  '28999',
#  '9373',
#  '31617',
#  '8185',
#  '19684',
#  '25075',
#  '17319',
#  '20320',
#  '21116',
#  '32064',
#  '15681',
#  '11990',
#  '12927',
#  '31383',
#  '2469',
#  '21500',
#  '4933',
#  '21212',
#  '12974',
#  '367',
#  '19773',
#  '7553',
#  '16500',
#  '17984',
#  '23355',
#  '10587',
#  '19628',
#  '31895',
#  '16349',
#  '27796',
#  '7806',
#  '13608',
#  '2427',
#  '8765',
#  '6128',
#  '20983',
#  '24368',
#  '3012',
#  '4519',
#  '7670',
#  '16815',
#  '26142',
#  '5599',
#  '13534',
#  '6320',
#  '30598',
#  '18053',
#  '26646',
#  '7483',
#  '20293',
#  '24231',
#  '18108',
#  '12134',
#  '10098',
#  '1046',
#  '25216',
#  '29283',
#  '31780',
#  '16106',
#  '13359',
#  '10106',
#  '27875',
#  '30253',
#  '22536',
#  '11117',
#  '11110',
#  '22812',
#  '3844',
#  '2098',
#  '25350',
#  '30648',
#  '6306',
#  '26391',
#  '14230',
#  '4234',
#  '31911',
#  '3174',
#  '18099',
#  '13839',
#  '15983',
#  '7704',
#  '32215',
#  '25913',
#  '19433',
#  '30941',
#  '18231',
#  '17521',
#  '10093',
#  '7859',
#  '8814',
#  '14029',
#  '5221',
#  '5940',
#  '2001',
#  '14',
#  '27078',
#  '29248',
#  '6325',
#  '26955',
#  '32442',
#  '10356',
#  '13538',
#  '15249',
#  '20990',
#  '12422',
#  '27571',
#  '3989',
#  '8700',
#  '24752',
#  '24524',
#  '29904',
#  '17745',
#  '27710',
#  '2149',
#  '15874',
#  '15113',
#  '9778',
#  '16385',
#  '18022',
#  '10028',
#  '25595',
#  '8399',
#  '6641',
#  '22265',
#  '16854',
#  '9627',
#  '6467',
#  '19274',
#  '4207',
#  '15975',
#  '31771',
#  '32596',
#  '8746',
#  '5926',
#  '2588',
#  '32202',
#  '6026',
#  '3352',
#  '24711',
#  '2538',
#  '11759',
#  '26522',
#  '25769',
#  '16392',
#  '7641',
#  '18598',
#  '23363',
#  '16783',
#  '28108',
#  '16387',
#  '9020',
#  '5765',
#  '7783',
#  '9219',
#  '26480',
#  '2136',
#  '7636',
#  '1469',
#  '31257',
#  '14688',
#  '1079',
#  '27575',
#  '6230',
#  '28226',
#  '21743',
#  '18257',
#  '27352',
#  '12748',
#  '2591',
#  '16585',
#  '470',
#  '22225',
#  '76',
#  '7216',
#  '25050',
#  '1439',
#  '26330',
#  '17880',
#  '6730',
#  '8092',
#  '3598',
#  '30042',
#  '10457',
#  '26455',
#  '13694',
#  '13223',
#  '22592',
#  '4514',
#  '21287',
#  '23269',
#  '17744',
#  '11415',
#  '13683',
#  '27311',
#  '23576',
#  '26461',
#  '16913',
#  '4463',
#  '13525',
#  '16608',
#  '22385',
#  '28320',
#  '1529',
#  '27688',
#  '26426',
#  '25412',
#  '9942',
#  '21211',
#  '30695',
#  '5342',
#  '7102',
#  '12867',
#  '30103',
#  '11060',
#  '13662',
#  '20142',
#  '18405',
#  '26292',
#  '29427',
#  '20056',
#  '5817',
#  '30516',
#  '8719',
#  '20917',
#  '5507',
#  '31358',
#  '7005',
#  '6241',
#  '18541',
#  '17431',
#  '29412',
#  '12023',
#  '5726',
#  '12908',
#  '8024',
#  '29248',
#  '6706',
#  '5119',
#  '2096',
#  '13484',
#  '18760',
#  '20308',
#  '16443',
#  '16161',
#  '19549',
#  '4610',
#  '25103',
#  '2905',
#  '23984',
#  '8264',
#  '30541',
#  '14759',
#  '23672',
#  '30023',
#  '26339',
#  '1081',
#  ...]

# %%
integerRDD.count()
# Out:
# Out[5]: 1010

# %%
newRDD = integerRDD.map(lambda x: float(x))

# %%
newRDD.collect()
# Out:
# Out[7]: [45687.0,
#  5463.0,
#  34443.0,
#  223.0,
#  456.0,
#  4667.0,
#  234.0,
#  9008.0,
#  1234.0,
#  2597.0,
#  6253.0,
#  10399.0,
#  3312.0,
#  2175.0,
#  20087.0,
#  6698.0,
#  31512.0,
#  618.0,
#  11698.0,
#  13969.0,
#  6575.0,
#  24846.0,
#  1313.0,
#  30977.0,
#  20927.0,
#  24771.0,
#  20293.0,
#  24210.0,
#  26005.0,
#  9680.0,
#  15297.0,
#  4099.0,
#  29625.0,
#  9374.0,
#  7645.0,
#  7660.0,
#  7025.0,
#  15755.0,
#  927.0,
#  22795.0,
#  7948.0,
#  29343.0,
#  23398.0,
#  5755.0,
#  27339.0,
#  19416.0,
#  3686.0,
#  21687.0,
#  16513.0,
#  32643.0,
#  10047.0,
#  11831.0,
#  14036.0,
#  11079.0,
#  23852.0,
#  11767.0,
#  18502.0,
#  28848.0,
#  21754.0,
#  30247.0,
#  16881.0,
#  28380.0,
#  19975.0,
#  22682.0,
#  8594.0,
#  18962.0,
#  9750.0,
#  17860.0,
#  26490.0,
#  11343.0,
#  6459.0,
#  10304.0,
#  18072.0,
#  19675.0,
#  26520.0,
#  28015.0,
#  21690.0,
#  20361.0,
#  25584.0,
#  31227.0,
#  9948.0,
#  29158.0,
#  3102.0,
#  16149.0,
#  20828.0,
#  3973.0,
#  15113.0,
#  9778.0,
#  16385.0,
#  18022.0,
#  10028.0,
#  25595.0,
#  8399.0,
#  6641.0,
#  22265.0,
#  16854.0,
#  9627.0,
#  6467.0,
#  19274.0,
#  4207.0,
#  15975.0,
#  31771.0,
#  32596.0,
#  8746.0,
#  5926.0,
#  2588.0,
#  32202.0,
#  6026.0,
#  3352.0,
#  24711.0,
#  2538.0,
#  11759.0,
#  26522.0,
#  25769.0,
#  16392.0,
#  7641.0,
#  18598.0,
#  23363.0,
#  16783.0,
#  28108.0,
#  16387.0,
#  9020.0,
#  5765.0,
#  7783.0,
#  9219.0,
#  26480.0,
#  2136.0,
#  7636.0,
#  1469.0,
#  31257.0,
#  14688.0,
#  1079.0,
#  27575.0,
#  6230.0,
#  28226.0,
#  21743.0,
#  18257.0,
#  27352.0,
#  12748.0,
#  2591.0,
#  16585.0,
#  470.0,
#  22225.0,
#  76.0,
#  7216.0,
#  25050.0,
#  1439.0,
#  26330.0,
#  17880.0,
#  6730.0,
#  8092.0,
#  3598.0,
#  30042.0,
#  10457.0,
#  26455.0,
#  13694.0,
#  13223.0,
#  22592.0,
#  4514.0,
#  21287.0,
#  23269.0,
#  17744.0,
#  11415.0,
#  13683.0,
#  27311.0,
#  23576.0,
#  26461.0,
#  16913.0,
#  4463.0,
#  13525.0,
#  16608.0,
#  22385.0,
#  28320.0,
#  1529.0,
#  27688.0,
#  26426.0,
#  25412.0,
#  9942.0,
#  21211.0,
#  30695.0,
#  5342.0,
#  7102.0,
#  12867.0,
#  30103.0,
#  11060.0,
#  13662.0,
#  20142.0,
#  18405.0,
#  26292.0,
#  29427.0,
#  20056.0,
#  5817.0,
#  30516.0,
#  8719.0,
#  20917.0,
#  5507.0,
#  31358.0,
#  7005.0,
#  6241.0,
#  18541.0,
#  17431.0,
#  29412.0,
#  12023.0,
#  5726.0,
#  12908.0,
#  8024.0,
#  29248.0,
#  6706.0,
#  5119.0,
#  2096.0,
#  13484.0,
#  18760.0,
#  20308.0,
#  16443.0,
#  16161.0,
#  19549.0,
#  4610.0,
#  25103.0,
#  2905.0,
#  23984.0,
#  8264.0,
#  30541.0,
#  14759.0,
#  23672.0,
#  30023.0,
#  26339.0,
#  1081.0,
#  ...]

# %%
print('The total number of even numbers = ',newRDD.filter(lambda x: x % 2 == 0).count())
# Out:
# The total number of even numbers =  514

# %%
print('The total number of odd numbers = ',newRDD.filter(lambda x: x % 2 != 0).count())
# Out:
# The total number of odd numbers =  496

# %% [markdown]
# **Part A Q2)**

# %%
salaryRDD = spark.sparkContext.textFile("/FileStore/tables/salary_1.txt", 4)

# %%
salaryRDD.collect()
# Out:
# Out[11]: ['Sales 9136',
#  'Research 13391',
#  'Developer 22220',
#  'QA 31888',
#  'Marketing 22215',
#  'Sales 45567',
#  'Research 4023',
#  'Developer 7262',
#  'QA 5243',
#  'Marketing 11425',
#  'Sales 11956',
#  'Research 24149',
#  'Developer 18258',
#  'QA 22962',
#  'Marketing 28960',
#  'Sales 8766',
#  'Research 18343',
#  'Developer 13686',
#  'QA 27626',
#  'Marketing 32430',
#  'Sales 761',
#  'Research 22690',
#  'Developer 11703',
#  'QA 591',
#  'Marketing 15249',
#  'Sales 15831',
#  'Research 28373',
#  'Developer 31034',
#  'QA 27821',
#  'Marketing 25192',
#  'Sales 12640',
#  'Research 15100',
#  'Developer 2781',
#  'QA 17773',
#  'Marketing 9047',
#  'Sales 20425',
#  'Research 19555',
#  'Developer 10498',
#  'QA 18714',
#  'Marketing 1209',
#  'Sales 16369',
#  'Research 3513',
#  'Developer 3362',
#  'QA 27723',
#  'Marketing 25341',
#  'Sales 28399',
#  'Research 15762',
#  'Developer 23792',
#  'QA 13328',
#  'Marketing 4390',
#  'Sales 32523',
#  'Research 16805',
#  'Developer 18811',
#  'QA 12468',
#  'Marketing 7741',
#  'Sales 23584',
#  'Research 16119',
#  'Developer 26166',
#  'QA 26373',
#  'Marketing 4961',
#  'Sales 30235',
#  'Research 28664',
#  'Developer 854',
#  'QA 1527',
#  'Marketing 19095',
#  'Sales 802',
#  'Research 12028',
#  'Developer 19730',
#  'QA 4230',
#  'Marketing 20693',
#  'Sales 30024',
#  'Research 26509',
#  'Developer 28672',
#  'QA 9694',
#  'Marketing 19383',
#  'Sales 5109',
#  'Research 30878',
#  'Developer 1891',
#  'QA 9489',
#  'Marketing 2365',
#  'Sales 4575',
#  'Research 30776',
#  'Developer 15514',
#  'QA 18658',
#  'Marketing 6825',
#  'Sales 1034',
#  'Research 17170',
#  'Developer 25976',
#  'QA 15512',
#  'Marketing 18823',
#  'Sales 30829',
#  'Research 22366',
#  'Developer 25931',
#  'QA 20532',
#  'Marketing 13467',
#  'Sales 27506',
#  'Research 17965',
#  'Developer 13427',
#  'QA 7150',
#  'Marketing 12812',
#  'Sales 17270',
#  'Research 1505',
#  'Developer 14103',
#  'QA 29018',
#  'Marketing 31533',
#  'Sales 27556',
#  'Research 28322',
#  'Developer 26138',
#  'QA 27642',
#  'Marketing 10195',
#  'Sales 7673',
#  'Research 27175',
#  'Developer 13211',
#  'QA 14649',
#  'Marketing 29983',
#  'Sales 29705',
#  'Research 5584',
#  'Developer 8096',
#  'QA 24383',
#  'Marketing 8854',
#  'Sales 14432',
#  'Research 17036',
#  'Developer 1777',
#  'QA 29267',
#  'Marketing 21468',
#  'Sales 18406',
#  'Research 23978',
#  'Developer 30412',
#  'QA 29962',
#  'Marketing 2840',
#  'Sales 650',
#  'Research 15323',
#  'Developer 11725',
#  'QA 761',
#  'Marketing 14115',
#  'Sales 32657',
#  'Research 2860',
#  'Developer 4006',
#  'QA 26615',
#  'Marketing 10112',
#  'Sales 28482',
#  'Research 31805',
#  'Developer 14928',
#  'QA 4086',
#  'Marketing 30092',
#  'Sales 27532',
#  'Research 23696',
#  'Developer 8319',
#  'QA 31889',
#  'Marketing 15785',
#  'Sales 14000',
#  'Research 5216',
#  'Developer 12595',
#  'QA 14051',
#  'Marketing 6920',
#  'Sales 26105',
#  'Research 21137',
#  'Developer 27454',
#  'QA 24189',
#  'Marketing 1198',
#  'Sales 19794',
#  'Research 21773',
#  'Developer 31047',
#  'QA 19052',
#  'Marketing 6715',
#  'Sales 6423',
#  'Research 15640',
#  'Developer 3861',
#  'QA 20108',
#  'Marketing 32632',
#  'Sales 20646',
#  'Research 31163',
#  'Developer 27634',
#  'QA 23862',
#  'Marketing 12730',
#  'Sales 16698',
#  'Research 23859',
#  'Developer 28518',
#  'QA 17903',
#  'Marketing 29377',
#  'Sales 14',
#  'Research 9572',
#  'Developer 24761',
#  'QA 6281',
#  'Marketing 24792',
#  'Sales 15736',
#  'Research 19475',
#  'Developer 8409',
#  'QA 1755',
#  'Marketing 8997',
#  'Sales 29146',
#  'Research 15029',
#  'Developer 31839',
#  'QA 32429',
#  'Marketing 4886',
#  'Sales 7763',
#  'Research 26173',
#  'Developer 12609',
#  'QA 22695',
#  'Marketing 30526',
#  'Sales 14834',
#  'Research 17919',
#  'Developer 7650',
#  'QA 30122',
#  'Marketing 1268',
#  'Sales 27729',
#  'Research 18526',
#  'Developer 6009',
#  'QA 4787',
#  'Marketing 13394',
#  'Sales 30214',
#  'Research 16710',
#  'Developer 28740',
#  'QA 14005',
#  'Marketing 16091',
#  'Sales 15170',
#  'Research 9875',
#  'Developer 12909',
#  'QA 12889',
#  'Marketing 6275',
#  'Sales 30224',
#  'Research 16947',
#  'Developer 14371',
#  'QA 5128',
#  'Marketing 8486',
#  'Sales 20113',
#  'Research 6527',
#  'Developer 2260',
#  'QA 8210',
#  'Marketing 7831',
#  'Sales 2958',
#  'Research 10202',
#  'Developer 27500',
#  'QA 15574',
#  'Marketing 4901',
#  'Sales 27305',
#  'Research 2814',
#  'Developer 24032',
#  'QA 15503',
#  'Marketing 24189',
#  'Sales 2799',
#  'Research 21723',
#  'Developer 5010',
#  'QA 27578',
#  'Marketing 3753',
#  'Sales 31069',
#  'Research 27804',
#  'Developer 31158',
#  'QA 9371',
#  'Marketing 31677',
#  'Sales 26733',
#  'Research 27101',
#  'Developer 27417',
#  'QA 21051',
#  'Marketing 14278',
#  'Sales 25464',
#  'Research 27002',
#  'Developer 25566',
#  'QA 4941',
#  'Marketing 25415',
#  'Sales 27655',
#  'Research 27384',
#  'Developer 22424',
#  'QA 17702',
#  'Marketing 31634',
#  'Sales 27723',
#  'Research 17206',
#  'Developer 11682',
#  'QA 30297',
#  'Marketing 29008',
#  'Sales 16292',
#  'Research 17355',
#  'Developer 22618',
#  'QA 8033',
#  'Marketing 20079',
#  'Sales 32347',
#  'Research 5467',
#  'Developer 10256',
#  'QA 14423',
#  'Marketing 4476',
#  'Sales 31074',
#  'Research 17419',
#  'Developer 12880',
#  'QA 22301',
#  'Marketing 22878',
#  'Sales 24379',
#  'Research 16716',
#  'Developer 29729',
#  'QA 14385',
#  'Marketing 7408',
#  'Sales 28480',
#  'Research 30269',
#  'Developer 22871',
#  'QA 27708',
#  'Marketing 31438',
#  'Sales 10725',
#  'Research 16407',
#  'Developer 30676',
#  'QA 14802',
#  'Marketing 31221',
#  'Sales 12777',
#  'Research 31849',
#  'Developer 11195',
#  'QA 14720',
#  'Marketing 16977',
#  'Sales 5622',
#  'Research 9286',
#  'Developer 17341',
#  'QA 28182',
#  'Marketing 2810',
#  'Sales 28628',
#  'Research 29840',
#  'Developer 29306',
#  'QA 1262',
#  'Marketing 19687',
#  'Sales 3473',
#  'Research 21681',
#  'Developer 20797',
#  'QA 12270',
#  'Marketing 30548',
#  'Sales 1102',
#  'Research 23601',
#  'Developer 24437',
#  'QA 8615',
#  'Marketing 3913',
#  'Sales 17942',
#  'Research 30392',
#  'Developer 26663',
#  'QA 1570',
#  'Marketing 22422',
#  'Sales 4347',
#  'Research 27687',
#  'Developer 9926',
#  'QA 20782',
#  'Marketing 21527',
#  'Sales 3206',
#  'Research 22698',
#  'Developer 10779',
#  'QA 11998',
#  'Marketing 7759',
#  'Sales 32372',
#  'Research 6442',
#  'Developer 29270',
#  'QA 11970',
#  'Marketing 8235',
#  'Sales 14181',
#  'Research 5781',
#  'Developer 22990',
#  'QA 13964',
#  'Marketing 20643',
#  'Sales 9933',
#  'Research 288',
#  'Developer 3947',
#  'QA 21',
#  'Marketing 14961',
#  'Sales 29701',
#  'Research 6164',
#  'Developer 30618',
#  'QA 28722',
#  'Marketing 7238',
#  'Sales 25432',
#  'Research 25922',
#  'Developer 6640',
#  'QA 2317',
#  'Marketing 32081',
#  'Sales 9483',
#  'Research 18203',
#  'Developer 26915',
#  'QA 19892',
#  'Marketing 5540',
#  'Sales 5126',
#  'Research 19763',
#  'Developer 3758',
#  'QA 28025',
#  'Marketing 26080',
#  'Sales 5710',
#  'Research 880',
#  'Developer 21053',
#  'QA 18163',
#  'Marketing 12903',
#  'Sales 18453',
#  'Research 6763',
#  'Developer 17360',
#  'QA 25271',
#  'Marketing 9979',
#  'Sales 19936',
#  'Research 20994',
#  'Developer 8742',
#  'QA 7529',
#  'Marketing 3376',
#  'Sales 27614',
#  'Research 2685',
#  'Developer 27142',
#  'QA 29028',
#  'Marketing 32629',
#  'Sales 13813',
#  'Research 8300',
#  'Developer 21349',
#  'QA 19099',
#  'Marketing 9499',
#  'Sales 13097',
#  'Research 32425',
#  'Developer 22510',
#  'QA 6183',
#  'Marketing 31853',
#  'Sales 4606',
#  'Research 26360',
#  'Developer 21896',
#  'QA 9187',
#  'Marketing 14130',
#  'Sales 31295',
#  'Research 6757',
#  'Developer 5817',
#  'QA 6240',
#  'Marketing 28733',
#  'Sales 32682',
#  'Research 14741',
#  'Developer 15679',
#  'QA 19966',
#  'Marketing 32075',
#  'Sales 26647',
#  'Research 2419',
#  'Developer 12565',
#  'QA 8887',
#  'Marketing 19958',
#  'Sales 4897',
#  'Research 1021',
#  'Developer 5495',
#  'QA 5477',
#  'Marketing 30336',
#  'Sales 31916',
#  'Research 14875',
#  'Developer 30131',
#  'QA 27290',
#  'Marketing 19878',
#  'Sales 9069',
#  'Research 4595',
#  'Developer 8681',
#  'QA 31415',
#  'Marketing 10554',
#  'Sales 31147',
#  'Research 7828',
#  'Developer 14949',
#  'QA 29625',
#  'Marketing 12651',
#  'Sales 17112',
#  'Research 16261',
#  'Developer 29898',
#  'QA 17417',
#  'Marketing 22131',
#  'Sales 25227',
#  'Research 18383',
#  'Developer 7130',
#  'QA 16617',
#  'Marketing 15716',
#  'Sales 8016',
#  'Research 2623',
#  'Developer 20430',
#  'QA 2240',
#  'Marketing 10531',
#  'Sales 3733',
#  'Research 11684',
#  'Developer 6924',
#  'QA 32306',
#  'Marketing 22396',
#  'Sales 14086',
#  'Research 5624',
#  'Developer 7726',
#  'QA 31720',
#  'Marketing 6713',
#  'Sales 27668',
#  'Research 23608',
#  'Developer 13014',
#  'QA 20073',
#  'Marketing 1616',
#  'Sales 4671',
#  'Research 2635',
#  'Developer 28801',
#  'QA 28008',
#  'Marketing 1787',
#  'Sales 29776',
#  'Research 20304',
#  'Developer 11393',
#  'QA 29519',
#  'Marketing 1052',
#  'Sales 26860',
#  'Research 12416',
#  'Developer 17802',
#  'QA 4087',
#  'Marketing 27809',
#  'Sales 23266',
#  'Research 21071',
#  'Developer 7441',
#  'QA 7687',
#  'Marketing 2326',
#  'Sales 12147',
#  'Research 28760',
#  'Developer 29608',
#  'QA 30206',
#  'Marketing 15846',
#  'Sales 1673',
#  'Research 19143',
#  'Developer 1143',
#  'QA 25646',
#  'Marketing 22548',
#  'Sales 20239',
#  'Research 13094',
#  'Developer 19572',
#  'QA 9774',
#  'Marketing 26291',
#  'Sales 7912',
#  'Research 21100',
#  'Developer 30665',
#  'QA 27997',
#  'Marketing 11698',
#  'Sales 23406',
#  'Research 16420',
#  'Developer 20911',
#  'QA 22272',
#  'Marketing 30606',
#  'Sales 26527',
#  'Research 21419',
#  'Developer 18113',
#  'QA 1423',
#  'Marketing 5612',
#  'Sales 25733',
#  'Research 5922',
#  'Developer 2502',
#  'QA 22901',
#  'Marketing 20553',
#  'Sales 10833',
#  'Research 22122',
#  'Developer 4718',
#  'QA 14461',
#  'Marketing 28477',
#  'Sales 12589',
#  'Research 15662',
#  'Developer 18713',
#  'QA 24512',
#  'Marketing 26454',
#  'Sales 3173',
#  'Research 30613',
#  'Developer 7389',
#  'QA 18266',
#  'Marketing 11172',
#  'Sales 22628',
#  'Research 16026',
#  'Developer 8011',
#  'QA 19767',
#  'Marketing 4022',
#  'Sales 5349',
#  'Research 7584',
#  'Developer 10874',
#  'QA 25585',
#  'Marketing 3136',
#  'Sales 875',
#  'Research 3555',
#  'Developer 1261',
#  'QA 1186',
#  'Marketing 18852',
#  'Sales 881',
#  'Research 7805',
#  'Developer 31052',
#  'QA 18340',
#  'Marketing 3076',
#  'Sales 12550',
#  'Research 8688',
#  'Developer 23374',
#  'QA 4228',
#  'Marketing 9575',
#  'Sales 19481',
#  'Research 22214',
#  'Developer 5412',
#  'QA 17145',
#  'Marketing 13193',
#  'Sales 15555',
#  'Research 17945',
#  'Developer 14243',
#  'QA 31664',
#  'Marketing 8324',
#  'Sales 4939',
#  'Research 27818',
#  'Developer 11409',
#  'QA 458',
#  'Marketing 11953',
#  'Sales 17069',
#  'Research 14800',
#  'Developer 12198',
#  'QA 31970',
#  'Marketing 5885',
#  'Sales 987',
#  'Research 15375',
#  'Developer 8872',
#  'QA 27138',
#  'Marketing 28145',
#  'Sales 9408',
#  'Research 23277',
#  'Developer 12220',
#  'QA 10821',
#  'Marketing 25595',
#  'Sales 9791',
#  'Research 19149',
#  'Developer 12189',
#  'QA 14524',
#  'Marketing 24663',
#  'Sales 11951',
#  'Research 2867',
#  'Developer 1398',
#  'QA 24454',
#  'Marketing 9394',
#  'Sales 26035',
#  'Research 7118',
#  'Developer 5035',
#  'QA 27529',
#  'Marketing 10907',
#  'Sales 32297',
#  'Research 3755',
#  'Developer 18448',
#  'QA 13365',
#  'Marketing 12421',
#  'Sales 5758',
#  'Research 21266',
#  'Developer 7615',
#  'QA 14214',
#  'Marketing 3275',
#  'Sales 15177',
#  'Research 31900',
#  'Developer 9558',
#  'QA 25971',
#  'Marketing 14464',
#  'Sales 4206',
#  'Research 24086',
#  'Developer 21743',
#  'QA 19263',
#  'Marketing 23787',
#  'Sales 28610',
#  'Research 29652',
#  'Developer 630',
#  'QA 25306',
#  'Marketing 6136',
#  'Sales 16703',
#  'Research 13786',
#  'Developer 20644',
#  'QA 4557',
#  'Marketing 31279',
#  'Sales 19390',
#  'Research 26122',
#  'Developer 30261',
#  'QA 19463',
#  'Marketing 5397',
#  'Sales 16758',
#  'Research 18465',
#  'Developer 18782',
#  'QA 25675',
#  'Marketing 6948',
#  'Sales 3413',
#  'Research 26921',
#  'Developer 12343',
#  'QA 5117',
#  'Marketing 1136',
#  'Sales 2876',
#  'Research 12549',
#  'Developer 25854',
#  'QA 2812',
#  'Marketing 28077',
#  'Sales 15625',
#  'Research 18631',
#  'Developer 13762',
#  'QA 582',
#  'Marketing 2383',
#  'Sales 22564',
#  'Research 22728',
#  'Developer 21782',
#  'QA 21693',
#  'Marketing 28365',
#  'Sales 30193',
#  'Research 19606',
#  'Developer 13725',
#  'QA 9528',
#  'Marketing 21759',
#  'Sales 24249',
#  'Research 29689',
#  'Developer 736',
#  'QA 26451',
#  'Marketing 7395',
#  'Sales 11590',
#  'Research 2708',
#  'Developer 21276',
#  'QA 7168',
#  'Marketing 1718',
#  'Sales 28641',
#  'Research 18105',
#  'Developer 22982',
#  'QA 210',
#  'Marketing 31213',
#  'Sales 2869',
#  'Research 26641',
#  'Developer 4663',
#  'QA 8983',
#  'Marketing 6084',
#  'Sales 955',
#  'Research 17214',
#  'Developer 16015',
#  'QA 21817',
#  'Marketing 26547',
#  'Sales 28542',
#  'Research 1834',
#  'Developer 2647',
#  'QA 4228',
#  'Marketing 4690',
#  'Sales 30514',
#  'Research 4985',
#  'Developer 11102',
#  'QA 27529',
#  'Marketing 14716',
#  'Sales 10545',
#  'Research 27972',
#  'Developer 16955',
#  'QA 44',
#  'Marketing 30244',
#  'Sales 25830',
#  'Research 25888',
#  'Developer 25691',
#  'QA 20424',
#  'Marketing 3467',
#  'Sales 26093',
#  'Research 26506',
#  'Developer 22529',
#  'QA 22868',
#  'Marketing 16032',
#  'Sales 22830',
#  'Research 1741',
#  'Developer 12647',
#  'QA 6393',
#  'Marketing 12866',
#  'Sales 14677',
#  'Research 6817',
#  'Developer 39',
#  'QA 11489',
#  'Marketing 2608',
#  'Sales 6172',
#  'Research 3844',
#  'Developer 7224',
#  'QA 26850',
#  'Marketing 7172',
#  'Sales 7623',
#  'Research 7345',
#  'Developer 25281',
#  'QA 13433',
#  'Marketing 14515',
#  'Sales 6361',
#  'Research 8495',
#  'Developer 15674',
#  'QA 2057',
#  'Marketing 24231',
#  'Sales 31978',
#  'Research 10765',
#  'Developer 23292',
#  'QA 6783',
#  'Marketing 13763',
#  'Sales 28289',
#  'Research 9300',
#  'Developer 17433',
#  'QA 26057',
#  'Marketing 9971',
#  'Sales 26003',
#  'Research 17004',
#  'Developer 25774',
#  'QA 3366',
#  'Marketing 23090',
#  'Sales 15458',
#  'Research 29145',
#  'Developer 13272',
#  'QA 1385',
#  'Marketing 31590',
#  'Sales 2831',
#  'Research 17497',
#  'Developer 1902',
#  'QA 30348',
#  'Marketing 7137',
#  'Sales 32307',
#  'Research 9487',
#  'Developer 10537',
#  'QA 32145',
#  'Marketing 23791',
#  'Sales 28331',
#  'Research 24490',
#  'Developer 27470',
#  'QA 31705',
#  'Marketing 2390',
#  'Sales 13971',
#  'Research 9820',
#  'Developer 6165',
#  'QA 17823',
#  'Marketing 1293',
#  'Sales 25014',
#  'Research 14693',
#  'Developer 23053',
#  'QA 24381',
#  'Marketing 29669',
#  'Sales 31562',
#  'Research 29278',
#  'Developer 14360',
#  'QA 31562',
#  'Marketing 24711',
#  'Sales 24584',
#  'Research 20722',
#  'Developer 6398',
#  'QA 5431',
#  'Marketing 31762',
#  'Sales 10834',
#  'Research 19173',
#  'Developer 22947',
#  'QA 14751',
#  'Marketing 13537',
#  'Sales 29318',
#  'Research 31370',
#  'Developer 22408',
#  'QA 24346',
#  'Marketing 32667',
#  'Sales 16820',
#  'Research 20916',
#  'Developer 11933',
#  'QA 1739',
#  'Marketing 6983',
#  'Sales 30873',
#  'Research 12421',
#  'Developer 4559',
#  'QA 23260',
#  'Marketing 25478',
#  'Sales 8009',
#  'Research 13537',
#  'Developer 27164',
#  'QA 1308',
#  'Marketing 19632',
#  'Sales 2683',
#  'Research 24645',
#  'Developer 8393',
#  'QA 15189',
#  'Marketing 29509',
#  'Sales 31564',
#  'Research 25977',
#  'Developer 17194',
#  'QA 9225',
#  'Marketing 990',
#  'Sales 9965',
#  'Research 22931',
#  'Developer 24995',
#  'QA 24848',
#  'Marketing 5381',
#  'Sales 11418',
#  'Research 4074',
#  'Developer 6544',
#  'QA 28224',
#  'Marketing 27930',
#  'Sales 26115',
#  'Research 3233',
#  'Developer 24953',
#  'QA 9427',
#  'Marketing 19839',
#  'Sales 29063',
#  'Research 958',
#  'Developer 19960',
#  'QA 7741',
#  'Marketing 5166',
#  'Sales 1847',
#  'Research 2503',
#  'Developer 5930',
#  'QA 31469',
#  'Marketing 11522',
#  'Sales 4826',
#  'Research 246',
#  'Developer 21965',
#  'QA 22160',
#  'Marketing 13571',
#  'Sales 3233',
#  'Research 27833',
#  'Developer 10666',
#  'QA 9751',
#  'Marketing 2269',
#  'Sales 15484',
#  'Research 9891',
#  'Developer 16392',
#  'QA 4245',
#  'Marketing 28696',
#  'Sales 24344',
#  'Research 17229',
#  'Developer 15952',
#  'QA 8569',
#  'Marketing 11715',
#  'Sales 10755',
#  'Research 22079',
#  'Developer 416',
#  'QA 28085',
#  'Marketing 15500',
#  'Sales 13792',
#  'Research 9028',
#  'Developer 2241',
#  'QA 22544',
#  'Marketing 11270',
#  'Sales 29814',
#  'Research 12566',
#  'Developer 26323',
#  'QA 23978',
#  'Marketing 32758',
#  'Sales 6389',
#  'Research 15709',
#  'Developer 32220',
#  'QA 14490',
#  'Marketing 10067',
#  'Sales 4498',
#  'Research 24734',
#  'Developer 24758',
#  'QA 6762',
#  'Marketing 25549',
#  'Sales 21740',
#  'Research 2229',
#  'Developer 24417',
#  'QA 3197',
#  'Marketing 11224',
#  'Sales 9357',
#  'Research 32542',
#  'Developer 11731',
#  'QA 12322',
#  'Marketing 14916',
#  'Sales 30903',
#  'Research 31232',
#  'Developer 29235',
#  'QA 9055',
#  'Marketing 2169',
#  'Sales 30844',
#  'Research 15234',
#  'Developer 10160',
#  'QA 18420',
#  'Marketing 5283',
#  'Sales 4747',
#  'Research 3104',
#  'Developer 12621',
#  'QA 25722',
#  'Marketing 23149',
#  'Sales 32682',
#  'Research 7281',
#  'Developer 29907',
#  'QA 9662',
#  'Marketing 12709',
#  'Sales 2671',
#  'Research 10884',
#  'Developer 26494',
#  'QA 13688',
#  'Marketing 6466',
#  'Sales 32716',
#  'Research 18751',
#  'Developer 27067',
#  'QA 18163',
#  'Marketing 6177',
#  'Sales 23644',
#  'Research 30986',
#  'Developer 16803',
#  'QA 28996',
#  'Marketing 21691',
#  'Sales 25206',
#  'Research 1827',
#  'Developer 11795',
#  'QA 1284',
#  'Marketing 32572',
#  'Sales 3589',
#  'Research 11594',
#  'Developer 3459',
#  'QA 24496',
#  'Marketing 17983',
#  'Sales 6116',
#  'Research 11566',
#  'Developer 26517',
#  'QA 16760',
#  'Marketing 29007',
#  'Sales 13492',
#  'Research 29463',
#  'Developer 4227',
#  'QA 25220',
#  'Marketing 6915',
#  'Sales 5812',
#  'Research 15460',
#  'Developer 8293',
#  'QA 5067',
#  'Marketing 14641',
#  'Sales 25791',
#  'Research 27903',
#  'Developer 10673',
#  'QA 31812',
#  'Marketing 9104',
#  'Sales 25745',
#  'Research 2361',
#  'Developer 17727',
#  'QA 28573',
#  'Marketing 29163',
#  'Sales 15298',
#  'Research 28164',
#  'Developer 3931',
#  'QA 29280',
#  'Marketing 9058',
#  ...]

# %%
salaryMapRDD = salaryRDD.map(lambda x: x.split(" "))
salaryMapRDD.collect()
# Out:
# Out[12]: [['Sales', '9136'],
#  ['Research', '13391'],
#  ['Developer', '22220'],
#  ['QA', '31888'],
#  ['Marketing', '22215'],
#  ['Sales', '45567'],
#  ['Research', '4023'],
#  ['Developer', '7262'],
#  ['QA', '5243'],
#  ['Marketing', '11425'],
#  ['Sales', '11956'],
#  ['Research', '24149'],
#  ['Developer', '18258'],
#  ['QA', '22962'],
#  ['Marketing', '28960'],
#  ['Sales', '8766'],
#  ['Research', '18343'],
#  ['Developer', '13686'],
#  ['QA', '27626'],
#  ['Marketing', '32430'],
#  ['Sales', '761'],
#  ['Research', '22690'],
#  ['Developer', '11703'],
#  ['QA', '591'],
#  ['Marketing', '15249'],
#  ['Sales', '15831'],
#  ['Research', '28373'],
#  ['Developer', '31034'],
#  ['QA', '27821'],
#  ['Marketing', '25192'],
#  ['Sales', '12640'],
#  ['Research', '15100'],
#  ['Developer', '2781'],
#  ['QA', '17773'],
#  ['Marketing', '9047'],
#  ['Sales', '20425'],
#  ['Research', '19555'],
#  ['Developer', '10498'],
#  ['QA', '18714'],
#  ['Marketing', '1209'],
#  ['Sales', '16369'],
#  ['Research', '3513'],
#  ['Developer', '3362'],
#  ['QA', '27723'],
#  ['Marketing', '25341'],
#  ['Sales', '28399'],
#  ['Research', '15762'],
#  ['Developer', '23792'],
#  ['QA', '13328'],
#  ['Marketing', '4390'],
#  ['Sales', '32523'],
#  ['Research', '16805'],
#  ['Developer', '18811'],
#  ['QA', '12468'],
#  ['Marketing', '7741'],
#  ['Sales', '23584'],
#  ['Research', '16119'],
#  ['Developer', '26166'],
#  ['QA', '26373'],
#  ['Marketing', '4961'],
#  ['Sales', '30235'],
#  ['Research', '28664'],
#  ['Developer', '854'],
#  ['QA', '1527'],
#  ['Marketing', '19095'],
#  ['Sales', '802'],
#  ['Research', '12028'],
#  ['Developer', '19730'],
#  ['QA', '4230'],
#  ['Marketing', '20693'],
#  ['Sales', '30024'],
#  ['Research', '26509'],
#  ['Developer', '28672'],
#  ['QA', '9694'],
#  ['Marketing', '19383'],
#  ['Sales', '5109'],
#  ['Research', '30878'],
#  ['Developer', '1891'],
#  ['QA', '9489'],
#  ['Marketing', '2365'],
#  ['Sales', '4575'],
#  ['Research', '30776'],
#  ['Developer', '15514'],
#  ['QA', '18658'],
#  ['Marketing', '6825'],
#  ['Sales', '1034'],
#  ['Research', '17170'],
#  ['Developer', '25976'],
#  ['QA', '15512'],
#  ['Marketing', '18823'],
#  ['Sales', '30829'],
#  ['Research', '22366'],
#  ['Developer', '25931'],
#  ['QA', '20532'],
#  ['Marketing', '13467'],
#  ['Sales', '27506'],
#  ['Research', '17965'],
#  ['Developer', '13427'],
#  ['QA', '7150'],
#  ['Marketing', '12812'],
#  ['Sales', '17270'],
#  ['Research', '1505'],
#  ['Developer', '14103'],
#  ['QA', '29018'],
#  ['Marketing', '31533'],
#  ['Sales', '27556'],
#  ['Research', '28322'],
#  ['Developer', '26138'],
#  ['QA', '27642'],
#  ['Marketing', '10195'],
#  ['Sales', '7673'],
#  ['Research', '27175'],
#  ['Developer', '13211'],
#  ['QA', '14649'],
#  ['Marketing', '29983'],
#  ['Sales', '29705'],
#  ['Research', '5584'],
#  ['Developer', '8096'],
#  ['QA', '24383'],
#  ['Marketing', '8854'],
#  ['Sales', '14432'],
#  ['Research', '17036'],
#  ['Developer', '1777'],
#  ['QA', '29267'],
#  ['Marketing', '21468'],
#  ['Sales', '18406'],
#  ['Research', '23978'],
#  ['Developer', '30412'],
#  ['QA', '29962'],
#  ['Marketing', '2840'],
#  ['Sales', '650'],
#  ['Research', '15323'],
#  ['Developer', '11725'],
#  ['QA', '761'],
#  ['Marketing', '14115'],
#  ['Sales', '32657'],
#  ['Research', '2860'],
#  ['Developer', '4006'],
#  ['QA', '26615'],
#  ['Marketing', '10112'],
#  ['Sales', '28482'],
#  ['Research', '31805'],
#  ['Developer', '14928'],
#  ['QA', '4086'],
#  ['Marketing', '30092'],
#  ['Sales', '27532'],
#  ['Research', '23696'],
#  ['Developer', '8319'],
#  ['QA', '31889'],
#  ['Marketing', '15785'],
#  ['Sales', '14000'],
#  ['Research', '5216'],
#  ['Developer', '12595'],
#  ['QA', '14051'],
#  ['Marketing', '6920'],
#  ['Sales', '26105'],
#  ['Research', '21137'],
#  ['Developer', '27454'],
#  ['QA', '24189'],
#  ['Marketing', '1198'],
#  ['Sales', '19794'],
#  ['Research', '21773'],
#  ['Developer', '31047'],
#  ['QA', '19052'],
#  ['Marketing', '6715'],
#  ['Sales', '6423'],
#  ['Research', '15640'],
#  ['Developer', '3861'],
#  ['QA', '20108'],
#  ['Marketing', '32632'],
#  ['Sales', '20646'],
#  ['Research', '31163'],
#  ['Developer', '27634'],
#  ['QA', '23862'],
#  ['Marketing', '12730'],
#  ['Sales', '16698'],
#  ['Research', '23859'],
#  ['Developer', '28518'],
#  ['QA', '17903'],
#  ['Marketing', '29377'],
#  ['Sales', '14'],
#  ['Research', '9572'],
#  ['Developer', '24761'],
#  ['QA', '6281'],
#  ['Marketing', '24792'],
#  ['Sales', '15736'],
#  ['Research', '19475'],
#  ['Developer', '8409'],
#  ['QA', '1755'],
#  ['Marketing', '8997'],
#  ['Sales', '29146'],
#  ['Research', '15029'],
#  ['Developer', '31839'],
#  ['QA', '32429'],
#  ['Marketing', '4886'],
#  ['Sales', '7763'],
#  ['Research', '26173'],
#  ['Developer', '12609'],
#  ['QA', '22695'],
#  ['Marketing', '30526'],
#  ['Sales', '14834'],
#  ['Research', '17919'],
#  ['Developer', '7650'],
#  ['QA', '30122'],
#  ['Marketing', '1268'],
#  ['Sales', '27729'],
#  ['Research', '18526'],
#  ['Developer', '6009'],
#  ['QA', '4787'],
#  ['Marketing', '13394'],
#  ['Sales', '30214'],
#  ['Research', '16710'],
#  ['Developer', '28740'],
#  ['QA', '14005'],
#  ['Marketing', '16091'],
#  ['Sales', '15170'],
#  ['Research', '9875'],
#  ['Developer', '12909'],
#  ['QA', '12889'],
#  ['Marketing', '6275'],
#  ['Sales', '30224'],
#  ['Research', '16947'],
#  ['Developer', '14371'],
#  ['QA', '5128'],
#  ['Marketing', '8486'],
#  ['Sales', '20113'],
#  ['Research', '6527'],
#  ['Developer', '2260'],
#  ['QA', '8210'],
#  ['Marketing', '7831'],
#  ['Sales', '2958'],
#  ['Research', '10202'],
#  ['Developer', '27500'],
#  ['QA', '15574'],
#  ['Marketing', '4901'],
#  ['Sales', '27305'],
#  ['Research', '2814'],
#  ['Developer', '24032'],
#  ['QA', '15503'],
#  ['Marketing', '24189'],
#  ['Sales', '2799'],
#  ['Research', '21723'],
#  ['Developer', '5010'],
#  ['QA', '27578'],
#  ['Marketing', '3753'],
#  ['Sales', '31069'],
#  ['Research', '27804'],
#  ['Developer', '31158'],
#  ['QA', '9371'],
#  ['Marketing', '31677'],
#  ['Sales', '26733'],
#  ['Research', '27101'],
#  ['Developer', '27417'],
#  ['QA', '21051'],
#  ['Marketing', '14278'],
#  ['Sales', '25464'],
#  ['Research', '27002'],
#  ['Developer', '25566'],
#  ['QA', '4941'],
#  ['Marketing', '25415'],
#  ['Sales', '27655'],
#  ['Research', '27384'],
#  ['Developer', '22424'],
#  ['QA', '17702'],
#  ['Marketing', '31634'],
#  ['Sales', '27723'],
#  ['Research', '17206'],
#  ['Developer', '11682'],
#  ['QA', '30297'],
#  ['Marketing', '29008'],
#  ['Sales', '16292'],
#  ['Research', '17355'],
#  ['Developer', '22618'],
#  ['QA', '8033'],
#  ['Marketing', '20079'],
#  ['Sales', '32347'],
#  ['Research', '5467'],
#  ['Developer', '10256'],
#  ['QA', '14423'],
#  ['Marketing', '4476'],
#  ['Sales', '31074'],
#  ['Research', '17419'],
#  ['Developer', '12880'],
#  ['QA', '22301'],
#  ['Marketing', '22878'],
#  ['Sales', '24379'],
#  ['Research', '16716'],
#  ['Developer', '29729'],
#  ['QA', '14385'],
#  ['Marketing', '7408'],
#  ['Sales', '28480'],
#  ['Research', '30269'],
#  ['Developer', '22871'],
#  ['QA', '27708'],
#  ['Marketing', '31438'],
#  ['Sales', '10725'],
#  ['Research', '16407'],
#  ['Developer', '30676'],
#  ['QA', '14802'],
#  ['Marketing', '31221'],
#  ['Sales', '12777'],
#  ['Research', '31849'],
#  ['Developer', '11195'],
#  ['QA', '14720'],
#  ['Marketing', '16977'],
#  ['Sales', '5622'],
#  ['Research', '9286'],
#  ['Developer', '17341'],
#  ['QA', '28182'],
#  ['Marketing', '2810'],
#  ['Sales', '28628'],
#  ['Research', '29840'],
#  ['Developer', '29306'],
#  ['QA', '1262'],
#  ['Marketing', '19687'],
#  ['Sales', '3473'],
#  ['Research', '21681'],
#  ['Developer', '20797'],
#  ['QA', '12270'],
#  ['Marketing', '30548'],
#  ['Sales', '1102'],
#  ['Research', '23601'],
#  ['Developer', '24437'],
#  ['QA', '8615'],
#  ['Marketing', '3913'],
#  ['Sales', '17942'],
#  ['Research', '30392'],
#  ['Developer', '26663'],
#  ['QA', '1570'],
#  ['Marketing', '22422'],
#  ['Sales', '4347'],
#  ['Research', '27687'],
#  ['Developer', '9926'],
#  ['QA', '20782'],
#  ['Marketing', '21527'],
#  ['Sales', '3206'],
#  ['Research', '22698'],
#  ['Developer', '10779'],
#  ['QA', '11998'],
#  ['Marketing', '7759'],
#  ['Sales', '32372'],
#  ['Research', '6442'],
#  ['Developer', '29270'],
#  ['QA', '11970'],
#  ['Marketing', '8235'],
#  ['Sales', '14181'],
#  ['Research', '5781'],
#  ['Developer', '22990'],
#  ['QA', '13964'],
#  ['Marketing', '20643'],
#  ['Sales', '9933'],
#  ['Research', '288'],
#  ['Developer', '3947'],
#  ['QA', '21'],
#  ['Marketing', '14961'],
#  ['Sales', '29701'],
#  ['Research', '6164'],
#  ['Developer', '30618'],
#  ['QA', '28722'],
#  ['Marketing', '7238'],
#  ['Sales', '25432'],
#  ['Research', '25922'],
#  ['Developer', '6640'],
#  ['QA', '2317'],
#  ['Marketing', '32081'],
#  ['Sales', '9483'],
#  ['Research', '18203'],
#  ['Developer', '26915'],
#  ['QA', '19892'],
#  ['Marketing', '5540'],
#  ['Sales', '5126'],
#  ['Research', '19763'],
#  ['Developer', '3758'],
#  ['QA', '28025'],
#  ['Marketing', '26080'],
#  ['Sales', '5710'],
#  ['Research', '880'],
#  ['Developer', '21053'],
#  ['QA', '18163'],
#  ['Marketing', '12903'],
#  ['Sales', '18453'],
#  ['Research', '6763'],
#  ['Developer', '17360'],
#  ['QA', '25271'],
#  ['Marketing', '9979'],
#  ['Sales', '19936'],
#  ['Research', '20994'],
#  ['Developer', '8742'],
#  ['QA', '7529'],
#  ['Marketing', '3376'],
#  ['Sales', '27614'],
#  ['Research', '2685'],
#  ['Developer', '27142'],
#  ['QA', '29028'],
#  ['Marketing', '32629'],
#  ['Sales', '13813'],
#  ['Research', '8300'],
#  ['Developer', '21349'],
#  ['QA', '19099'],
#  ['Marketing', '9499'],
#  ['Sales', '13097'],
#  ['Research', '32425'],
#  ['Developer', '22510'],
#  ['QA', '6183'],
#  ['Marketing', '31853'],
#  ['Sales', '4606'],
#  ['Research', '26360'],
#  ['Developer', '21896'],
#  ['QA', '9187'],
#  ['Marketing', '14130'],
#  ['Sales', '31295'],
#  ['Research', '6757'],
#  ['Developer', '5817'],
#  ['QA', '6240'],
#  ['Marketing', '28733'],
#  ['Sales', '32682'],
#  ['Research', '14741'],
#  ['Developer', '15679'],
#  ['QA', '19966'],
#  ['Marketing', '32075'],
#  ['Sales', '26647'],
#  ['Research', '2419'],
#  ['Developer', '12565'],
#  ['QA', '8887'],
#  ['Marketing', '19958'],
#  ['Sales', '4897'],
#  ['Research', '1021'],
#  ['Developer', '5495'],
#  ['QA', '5477'],
#  ['Marketing', '30336'],
#  ['Sales', '31916'],
#  ['Research', '14875'],
#  ['Developer', '30131'],
#  ['QA', '27290'],
#  ['Marketing', '19878'],
#  ['Sales', '9069'],
#  ['Research', '4595'],
#  ['Developer', '8681'],
#  ['QA', '31415'],
#  ['Marketing', '10554'],
#  ['Sales', '31147'],
#  ['Research', '7828'],
#  ['Developer', '14949'],
#  ['QA', '29625'],
#  ['Marketing', '12651'],
#  ['Sales', '17112'],
#  ['Research', '16261'],
#  ['Developer', '29898'],
#  ['QA', '17417'],
#  ['Marketing', '22131'],
#  ['Sales', '25227'],
#  ['Research', '18383'],
#  ['Developer', '7130'],
#  ['QA', '16617'],
#  ['Marketing', '15716'],
#  ['Sales', '8016'],
#  ['Research', '2623'],
#  ['Developer', '20430'],
#  ['QA', '2240'],
#  ['Marketing', '10531'],
#  ['Sales', '3733'],
#  ['Research', '11684'],
#  ['Developer', '6924'],
#  ['QA', '32306'],
#  ['Marketing', '22396'],
#  ['Sales', '14086'],
#  ['Research', '5624'],
#  ['Developer', '7726'],
#  ['QA', '31720'],
#  ['Marketing', '6713'],
#  ['Sales', '27668'],
#  ['Research', '23608'],
#  ['Developer', '13014'],
#  ['QA', '20073'],
#  ['Marketing', '1616'],
#  ['Sales', '4671'],
#  ['Research', '2635'],
#  ['Developer', '28801'],
#  ['QA', '28008'],
#  ['Marketing', '1787'],
#  ['Sales', '29776'],
#  ['Research', '20304'],
#  ['Developer', '11393'],
#  ['QA', '29519'],
#  ['Marketing', '1052'],
#  ['Sales', '26860'],
#  ['Research', '12416'],
#  ['Developer', '17802'],
#  ['QA', '4087'],
#  ['Marketing', '27809'],
#  ['Sales', '23266'],
#  ['Research', '21071'],
#  ['Developer', '7441'],
#  ['QA', '7687'],
#  ['Marketing', '2326'],
#  ['Sales', '12147'],
#  ['Research', '28760'],
#  ['Developer', '29608'],
#  ['QA', '30206'],
#  ['Marketing', '15846'],
#  ['Sales', '1673'],
#  ['Research', '19143'],
#  ['Developer', '1143'],
#  ['QA', '25646'],
#  ['Marketing', '22548'],
#  ['Sales', '20239'],
#  ['Research', '13094'],
#  ['Developer', '19572'],
#  ['QA', '9774'],
#  ['Marketing', '26291'],
#  ['Sales', '7912'],
#  ['Research', '21100'],
#  ['Developer', '30665'],
#  ['QA', '27997'],
#  ['Marketing', '11698'],
#  ['Sales', '23406'],
#  ['Research', '16420'],
#  ['Developer', '20911'],
#  ['QA', '22272'],
#  ['Marketing', '30606'],
#  ['Sales', '26527'],
#  ['Research', '21419'],
#  ['Developer', '18113'],
#  ['QA', '1423'],
#  ['Marketing', '5612'],
#  ['Sales', '25733'],
#  ['Research', '5922'],
#  ['Developer', '2502'],
#  ['QA', '22901'],
#  ['Marketing', '20553'],
#  ['Sales', '10833'],
#  ['Research', '22122'],
#  ['Developer', '4718'],
#  ['QA', '14461'],
#  ['Marketing', '28477'],
#  ['Sales', '12589'],
#  ['Research', '15662'],
#  ['Developer', '18713'],
#  ['QA', '24512'],
#  ['Marketing', '26454'],
#  ['Sales', '3173'],
#  ['Research', '30613'],
#  ['Developer', '7389'],
#  ['QA', '18266'],
#  ['Marketing', '11172'],
#  ['Sales', '22628'],
#  ['Research', '16026'],
#  ['Developer', '8011'],
#  ['QA', '19767'],
#  ['Marketing', '4022'],
#  ['Sales', '5349'],
#  ['Research', '7584'],
#  ['Developer', '10874'],
#  ['QA', '25585'],
#  ['Marketing', '3136'],
#  ['Sales', '875'],
#  ['Research', '3555'],
#  ['Developer', '1261'],
#  ['QA', '1186'],
#  ['Marketing', '18852'],
#  ['Sales', '881'],
#  ['Research', '7805'],
#  ['Developer', '31052'],
#  ['QA', '18340'],
#  ['Marketing', '3076'],
#  ['Sales', '12550'],
#  ['Research', '8688'],
#  ['Developer', '23374'],
#  ['QA', '4228'],
#  ['Marketing', '9575'],
#  ['Sales', '19481'],
#  ['Research', '22214'],
#  ['Developer', '5412'],
#  ['QA', '17145'],
#  ['Marketing', '13193'],
#  ['Sales', '15555'],
#  ['Research', '17945'],
#  ['Developer', '14243'],
#  ['QA', '31664'],
#  ['Marketing', '8324'],
#  ['Sales', '4939'],
#  ['Research', '27818'],
#  ['Developer', '11409'],
#  ['QA', '458'],
#  ['Marketing', '11953'],
#  ['Sales', '17069'],
#  ['Research', '14800'],
#  ['Developer', '12198'],
#  ['QA', '31970'],
#  ['Marketing', '5885'],
#  ['Sales', '987'],
#  ['Research', '15375'],
#  ['Developer', '8872'],
#  ['QA', '27138'],
#  ['Marketing', '28145'],
#  ['Sales', '9408'],
#  ['Research', '23277'],
#  ['Developer', '12220'],
#  ['QA', '10821'],
#  ['Marketing', '25595'],
#  ['Sales', '9791'],
#  ['Research', '19149'],
#  ['Developer', '12189'],
#  ['QA', '14524'],
#  ['Marketing', '24663'],
#  ['Sales', '11951'],
#  ['Research', '2867'],
#  ['Developer', '1398'],
#  ['QA', '24454'],
#  ['Marketing', '9394'],
#  ['Sales', '26035'],
#  ['Research', '7118'],
#  ['Developer', '5035'],
#  ['QA', '27529'],
#  ['Marketing', '10907'],
#  ['Sales', '32297'],
#  ['Research', '3755'],
#  ['Developer', '18448'],
#  ['QA', '13365'],
#  ['Marketing', '12421'],
#  ['Sales', '5758'],
#  ['Research', '21266'],
#  ['Developer', '7615'],
#  ['QA', '14214'],
#  ['Marketing', '3275'],
#  ['Sales', '15177'],
#  ['Research', '31900'],
#  ['Developer', '9558'],
#  ['QA', '25971'],
#  ['Marketing', '14464'],
#  ['Sales', '4206'],
#  ['Research', '24086'],
#  ['Developer', '21743'],
#  ['QA', '19263'],
#  ['Marketing', '23787'],
#  ['Sales', '28610'],
#  ['Research', '29652'],
#  ['Developer', '630'],
#  ['QA', '25306'],
#  ['Marketing', '6136'],
#  ['Sales', '16703'],
#  ['Research', '13786'],
#  ['Developer', '20644'],
#  ['QA', '4557'],
#  ['Marketing', '31279'],
#  ['Sales', '19390'],
#  ['Research', '26122'],
#  ['Developer', '30261'],
#  ['QA', '19463'],
#  ['Marketing', '5397'],
#  ['Sales', '16758'],
#  ['Research', '18465'],
#  ['Developer', '18782'],
#  ['QA', '25675'],
#  ['Marketing', '6948'],
#  ['Sales', '3413'],
#  ['Research', '26921'],
#  ['Developer', '12343'],
#  ['QA', '5117'],
#  ['Marketing', '1136'],
#  ['Sales', '2876'],
#  ['Research', '12549'],
#  ['Developer', '25854'],
#  ['QA', '2812'],
#  ['Marketing', '28077'],
#  ['Sales', '15625'],
#  ['Research', '18631'],
#  ['Developer', '13762'],
#  ['QA', '582'],
#  ['Marketing', '2383'],
#  ['Sales', '22564'],
#  ['Research', '22728'],
#  ['Developer', '21782'],
#  ['QA', '21693'],
#  ['Marketing', '28365'],
#  ['Sales', '30193'],
#  ['Research', '19606'],
#  ['Developer', '13725'],
#  ['QA', '9528'],
#  ['Marketing', '21759'],
#  ['Sales', '24249'],
#  ['Research', '29689'],
#  ['Developer', '736'],
#  ['QA', '26451'],
#  ['Marketing', '7395'],
#  ['Sales', '11590'],
#  ['Research', '2708'],
#  ['Developer', '21276'],
#  ['QA', '7168'],
#  ['Marketing', '1718'],
#  ['Sales', '28641'],
#  ['Research', '18105'],
#  ['Developer', '22982'],
#  ['QA', '210'],
#  ['Marketing', '31213'],
#  ['Sales', '2869'],
#  ['Research', '26641'],
#  ['Developer', '4663'],
#  ['QA', '8983'],
#  ['Marketing', '6084'],
#  ['Sales', '955'],
#  ['Research', '17214'],
#  ['Developer', '16015'],
#  ['QA', '21817'],
#  ['Marketing', '26547'],
#  ['Sales', '28542'],
#  ['Research', '1834'],
#  ['Developer', '2647'],
#  ['QA', '4228'],
#  ['Marketing', '4690'],
#  ['Sales', '30514'],
#  ['Research', '4985'],
#  ['Developer', '11102'],
#  ['QA', '27529'],
#  ['Marketing', '14716'],
#  ['Sales', '10545'],
#  ['Research', '27972'],
#  ['Developer', '16955'],
#  ['QA', '44'],
#  ['Marketing', '30244'],
#  ['Sales', '25830'],
#  ['Research', '25888'],
#  ['Developer', '25691'],
#  ['QA', '20424'],
#  ['Marketing', '3467'],
#  ['Sales', '26093'],
#  ['Research', '26506'],
#  ['Developer', '22529'],
#  ['QA', '22868'],
#  ['Marketing', '16032'],
#  ['Sales', '22830'],
#  ['Research', '1741'],
#  ['Developer', '12647'],
#  ['QA', '6393'],
#  ['Marketing', '12866'],
#  ['Sales', '14677'],
#  ['Research', '6817'],
#  ['Developer', '39'],
#  ['QA', '11489'],
#  ['Marketing', '2608'],
#  ['Sales', '6172'],
#  ['Research', '3844'],
#  ['Developer', '7224'],
#  ['QA', '26850'],
#  ['Marketing', '7172'],
#  ['Sales', '7623'],
#  ['Research', '7345'],
#  ['Developer', '25281'],
#  ['QA', '13433'],
#  ['Marketing', '14515'],
#  ['Sales', '6361'],
#  ['Research', '8495'],
#  ['Developer', '15674'],
#  ['QA', '2057'],
#  ['Marketing', '24231'],
#  ['Sales', '31978'],
#  ['Research', '10765'],
#  ['Developer', '23292'],
#  ['QA', '6783'],
#  ['Marketing', '13763'],
#  ['Sales', '28289'],
#  ['Research', '9300'],
#  ['Developer', '17433'],
#  ['QA', '26057'],
#  ['Marketing', '9971'],
#  ['Sales', '26003'],
#  ['Research', '17004'],
#  ['Developer', '25774'],
#  ['QA', '3366'],
#  ['Marketing', '23090'],
#  ['Sales', '15458'],
#  ['Research', '29145'],
#  ['Developer', '13272'],
#  ['QA', '1385'],
#  ['Marketing', '31590'],
#  ['Sales', '2831'],
#  ['Research', '17497'],
#  ['Developer', '1902'],
#  ['QA', '30348'],
#  ['Marketing', '7137'],
#  ['Sales', '32307'],
#  ['Research', '9487'],
#  ['Developer', '10537'],
#  ['QA', '32145'],
#  ['Marketing', '23791'],
#  ['Sales', '28331'],
#  ['Research', '24490'],
#  ['Developer', '27470'],
#  ['QA', '31705'],
#  ['Marketing', '2390'],
#  ['Sales', '13971'],
#  ['Research', '9820'],
#  ['Developer', '6165'],
#  ['QA', '17823'],
#  ['Marketing', '1293'],
#  ['Sales', '25014'],
#  ['Research', '14693'],
#  ['Developer', '23053'],
#  ['QA', '24381'],
#  ['Marketing', '29669'],
#  ['Sales', '31562'],
#  ['Research', '29278'],
#  ['Developer', '14360'],
#  ['QA', '31562'],
#  ['Marketing', '24711'],
#  ['Sales', '24584'],
#  ['Research', '20722'],
#  ['Developer', '6398'],
#  ['QA', '5431'],
#  ['Marketing', '31762'],
#  ['Sales', '10834'],
#  ['Research', '19173'],
#  ['Developer', '22947'],
#  ['QA', '14751'],
#  ['Marketing', '13537'],
#  ['Sales', '29318'],
#  ['Research', '31370'],
#  ['Developer', '22408'],
#  ['QA', '24346'],
#  ['Marketing', '32667'],
#  ['Sales', '16820'],
#  ['Research', '20916'],
#  ['Developer', '11933'],
#  ['QA', '1739'],
#  ['Marketing', '6983'],
#  ['Sales', '30873'],
#  ['Research', '12421'],
#  ['Developer', '4559'],
#  ['QA', '23260'],
#  ['Marketing', '25478'],
#  ['Sales', '8009'],
#  ['Research', '13537'],
#  ['Developer', '27164'],
#  ['QA', '1308'],
#  ['Marketing', '19632'],
#  ['Sales', '2683'],
#  ['Research', '24645'],
#  ['Developer', '8393'],
#  ['QA', '15189'],
#  ['Marketing', '29509'],
#  ['Sales', '31564'],
#  ['Research', '25977'],
#  ['Developer', '17194'],
#  ['QA', '9225'],
#  ['Marketing', '990'],
#  ['Sales', '9965'],
#  ['Research', '22931'],
#  ['Developer', '24995'],
#  ['QA', '24848'],
#  ['Marketing', '5381'],
#  ['Sales', '11418'],
#  ['Research', '4074'],
#  ['Developer', '6544'],
#  ['QA', '28224'],
#  ['Marketing', '27930'],
#  ['Sales', '26115'],
#  ['Research', '3233'],
#  ['Developer', '24953'],
#  ['QA', '9427'],
#  ['Marketing', '19839'],
#  ['Sales', '29063'],
#  ['Research', '958'],
#  ['Developer', '19960'],
#  ['QA', '7741'],
#  ['Marketing', '5166'],
#  ['Sales', '1847'],
#  ['Research', '2503'],
#  ['Developer', '5930'],
#  ['QA', '31469'],
#  ['Marketing', '11522'],
#  ['Sales', '4826'],
#  ['Research', '246'],
#  ['Developer', '21965'],
#  ['QA', '22160'],
#  ['Marketing', '13571'],
#  ['Sales', '3233'],
#  ['Research', '27833'],
#  ['Developer', '10666'],
#  ['QA', '9751'],
#  ['Marketing', '2269'],
#  ['Sales', '15484'],
#  ['Research', '9891'],
#  ['Developer', '16392'],
#  ['QA', '4245'],
#  ['Marketing', '28696'],
#  ['Sales', '24344'],
#  ['Research', '17229'],
#  ['Developer', '15952'],
#  ['QA', '8569'],
#  ['Marketing', '11715'],
#  ['Sales', '10755'],
#  ['Research', '22079'],
#  ['Developer', '416'],
#  ['QA', '28085'],
#  ['Marketing', '15500'],
#  ['Sales', '13792'],
#  ['Research', '9028'],
#  ['Developer', '2241'],
#  ['QA', '22544'],
#  ['Marketing', '11270'],
#  ['Sales', '29814'],
#  ['Research', '12566'],
#  ['Developer', '26323'],
#  ['QA', '23978'],
#  ['Marketing', '32758'],
#  ['Sales', '6389'],
#  ['Research', '15709'],
#  ['Developer', '32220'],
#  ['QA', '14490'],
#  ['Marketing', '10067'],
#  ['Sales', '4498'],
#  ['Research', '24734'],
#  ['Developer', '24758'],
#  ['QA', '6762'],
#  ['Marketing', '25549'],
#  ['Sales', '21740'],
#  ['Research', '2229'],
#  ['Developer', '24417'],
#  ['QA', '3197'],
#  ['Marketing', '11224'],
#  ['Sales', '9357'],
#  ['Research', '32542'],
#  ['Developer', '11731'],
#  ['QA', '12322'],
#  ['Marketing', '14916'],
#  ['Sales', '30903'],
#  ['Research', '31232'],
#  ['Developer', '29235'],
#  ['QA', '9055'],
#  ['Marketing', '2169'],
#  ['Sales', '30844'],
#  ['Research', '15234'],
#  ['Developer', '10160'],
#  ['QA', '18420'],
#  ['Marketing', '5283'],
#  ['Sales', '4747'],
#  ['Research', '3104'],
#  ['Developer', '12621'],
#  ['QA', '25722'],
#  ['Marketing', '23149'],
#  ['Sales', '32682'],
#  ['Research', '7281'],
#  ['Developer', '29907'],
#  ['QA', '9662'],
#  ['Marketing', '12709'],
#  ['Sales', '2671'],
#  ['Research', '10884'],
#  ['Developer', '26494'],
#  ['QA', '13688'],
#  ['Marketing', '6466'],
#  ['Sales', '32716'],
#  ['Research', '18751'],
#  ['Developer', '27067'],
#  ['QA', '18163'],
#  ['Marketing', '6177'],
#  ['Sales', '23644'],
#  ['Research', '30986'],
#  ['Developer', '16803'],
#  ['QA', '28996'],
#  ['Marketing', '21691'],
#  ['Sales', '25206'],
#  ['Research', '1827'],
#  ['Developer', '11795'],
#  ['QA', '1284'],
#  ['Marketing', '32572'],
#  ['Sales', '3589'],
#  ['Research', '11594'],
#  ['Developer', '3459'],
#  ['QA', '24496'],
#  ['Marketing', '17983'],
#  ['Sales', '6116'],
#  ['Research', '11566'],
#  ['Developer', '26517'],
#  ['QA', '16760'],
#  ['Marketing', '29007'],
#  ['Sales', '13492'],
#  ['Research', '29463'],
#  ['Developer', '4227'],
#  ['QA', '25220'],
#  ['Marketing', '6915'],
#  ['Sales', '5812'],
#  ['Research', '15460'],
#  ['Developer', '8293'],
#  ['QA', '5067'],
#  ['Marketing', '14641'],
#  ['Sales', '25791'],
#  ['Research', '27903'],
#  ['Developer', '10673'],
#  ['QA', '31812'],
#  ['Marketing', '9104'],
#  ['Sales', '25745'],
#  ['Research', '2361'],
#  ['Developer', '17727'],
#  ['QA', '28573'],
#  ['Marketing', '29163'],
#  ['Sales', '15298'],
#  ['Research', '28164'],
#  ['Developer', '3931'],
#  ['QA', '29280'],
#  ['Marketing', '9058'],
#  ...]

# %%
print("Salary sum per department")
mappedRDD = salaryMapRDD.map(lambda x: (x[0], int(x[1])))
sumRDD = mappedRDD.reduceByKey(lambda x,y: x+y)
sumRDD.collect()
# Out:
# Salary sum per department
# Out[13]: [('Developer', 3221394),
#  ('Sales', 3488491),
#  ('Research', 3328284),
#  ('QA', 3360624),
#  ('Marketing', 3158450)]

# %% [markdown]
# **Part A Q3)**

# %%
textFile = spark.read.text("/FileStore/tables/shakespeare_2.txt")

# %%
print('As per the question, only exact words were counted')
print('Shakespeare ',textFile.rdd.map(lambda x: x[0].split(' ').count('Shakespeare')).sum())
print('why ',textFile.rdd.map(lambda x: x[0].split(' ').count('why')).sum())
print('Lord ',textFile.rdd.map(lambda x: x[0].split(' ').count('Lord')).sum())
print('Library ',textFile.rdd.map(lambda x: x[0].split(' ').count('Library')).sum())
print('GLUTENBERG ',textFile.rdd.map(lambda x: x[0].split(' ').count('GUTENBERG')).sum())
print('WILLIAM ',textFile.rdd.map(lambda x: x[0].split(' ').count('WILLIAM')).sum())
print('COLLEGE ',textFile.rdd.map(lambda x: x[0].split(' ').count('COLLEGE')).sum())
print('WORLD ',textFile.rdd.map(lambda x: x[0].split(' ').count('WORLD')).sum())
# Out:
# As per the question, only exact words were counted
# Shakespeare  22
# why  91
# Lord  341
# Library  2
# GLUTENBERG  99
# WILLIAM  115
# COLLEGE  98
# WORLD  98

# %% [markdown]
# **Part A Q4)**

# %%
shakespeare_2RDD = spark.sparkContext.textFile("/FileStore/tables/shakespeare_2.txt").flatMap(lambda line: line.split())

# %%
mapRDD = shakespeare_2RDD.map(lambda word: (word, 1))
resultRDD = mapRDD.reduceByKey(lambda a,b:a+b)

# %%
print('The top 10 most occuring words with their counts are ',resultRDD.map(lambda x: (x[1], x[0])).sortByKey(False).take(11))
# Out:
# The top 10 most occuring words with their counts are  [(11397, 'the'), (8777, 'and'), (8556, 'I'), (7873, 'of'), (7421, 'to'), (5672, 'a'), (4913, 'my'), (4600, 'in'), (4060, 'you'), (3547, 'And'), (3522, 'that')]

# %%
print('The top 10 least occuring words with their counts are ',resultRDD.map(lambda x: (x[1], x[0])).sortByKey(True).take(10))
# Out:
# The top 10 least occuring words with their counts are  [(1, 'anyone'), (1, 'restrictions'), (1, 'whatsoever.'), (1, 're-use'), (1, 'online'), (1, 'www.gutenberg.org'), (1, 'COPYRIGHTED'), (1, 'eBook,'), (1, 'Details'), (1, 'guidelines')]

# %% [markdown]
# **Part B**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

from pyspark.ml.feature import Imputer, StringIndexer, VectorAssembler
from pyspark.ml.linalg import SparseVector, DenseVector
from pyspark.ml import Pipeline
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
spark = SparkSession.builder.appName("Recommender systems").getOrCreate()

#set the shuffle partition same as number of cpu cores to improve performance 
spark.conf.set("spark.sql.shuffle.partitions", 4)

# %%
path = "/FileStore/tables/movies_1.csv"

df = spark.read \
  .format("csv") \
  .option("inferSchema", True) \
  .option("header", True) \
  .option("sep", ',') \
  .option("path", path) \
  .load()

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
</td></tr><tr><td>41</td><td>2</td><td>1</td></tr><tr><td>43</td><td>1</td><td>1</td></tr><tr><td>44</td><td>1</td><td>1</td></tr><tr><td>47</td><td>1</td><td>1</td></tr><tr><td>50</td><td>1</td><td>1</td></tr><tr><td>54</td><td>1</td><td>1</td></tr><tr><td>56</td><td>2</td><td>1</td></tr><tr><td>57</td><td>1</td><td>1</td></tr><tr><td>58</td><td>1</td><td>1</td></tr><tr><td>60</td><td>1</td><td>1</td></tr><tr><td>62</td><td>4</td><td>1</td></tr><tr><td>63</td><td>1</td><td>1</td></tr><tr><td>67</td><td>1</td><td>1</td></tr><tr><td>68</td><td>4</td><td>1</td></tr><tr><td>70</td><td>2</td><td>1</td></tr><tr><td>72</td><td>1</td><td>1</td></tr><tr><td>73</td><td>1</td><td>1</td></tr><tr><td>74</td><td>2</td><td>1</td></tr><tr><td>76</td><td>1</td><td>1</td></tr><tr><td>77</td><td>3</td><td>1</td></tr><tr><td>78</td><td>1</td><td>1</td></tr><tr><td>81</td><td>1</td><td>1</td></tr><tr><td>82</td><td>1</td><td>1</td></tr><tr><td>85</td><td>3</td><td>1</td></tr><tr><td>86</td><td>2</td><td>1</td></tr><tr><td>88</td><td>2</td><td>1</td></tr><tr><td>91</td><td>1</td><td>1</td></tr><tr><td>92</td><td>2</td><td>1</td></tr><tr><td>93</td><td>1</td><td>1</td></tr><tr><td>94</td><td>2</td><td ...

# %% [markdown]
# The csv file consists of 3 columns namely movieId, rating and userId.<br>The ratings are out of 5 (5 means very good movie and 1 means poor).<br>

# %% [markdown]
# **Part B Q1)**

# %%
print("Top 20 movies with highest ratings")
new_df = df.groupBy("movieId").agg(count("rating")).orderBy(col("count(rating)").desc())
new_df.show(20)
# Out:
# Top 20 movies with highest ratings
# +-------+-------------+
# |movieId|count(rating)|
# +-------+-------------+
# |     51|           20|
# |     50|           20|
# |      6|           20|
# |     29|           20|
# |     22|           20|
# |     15|           19|
# |     55|           19|
# |     68|           19|
# |      2|           19|
# |     94|           19|
# |     86|           18|
# |     45|           18|
# |     36|           18|
# |     14|           18|
# |     88|           18|
# |     85|           18|
# |     19|           17|
# |     12|           17|
# |     67|           17|
# |     56|           17|
# +-------+-------------+
# only showing top 20 rows

# %%
print("Top 15 users who provided the highest ratings")
new_df_2 = df.groupBy("userId").agg(count("rating")).orderBy(col("count(rating)").desc())
new_df_2.show(15)
# Out:
# Top 15 users who provided the highest ratings
# +------+-------------+
# |userId|count(rating)|
# +------+-------------+
# |    14|           57|
# |     6|           57|
# |    22|           56|
# |    11|           56|
# |    12|           55|
# |     4|           55|
# |     7|           54|
# |     9|           53|
# |    23|           52|
# |    24|           52|
# |    18|           52|
# |    28|           50|
# |    19|           49|
# |     1|           49|
# |     5|           49|
# +------+-------------+
# only showing top 15 rows

# %% [markdown]
# **Part B Q2)**

# %%
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit, CrossValidator

# %% [markdown]
# Combination 1: 60% Train set and 40% Test set

# %%
(training_1, test_1) = df.randomSplit([0.6, 0.4], 20)   #### Setting a constant seed value so that the split remais constant throughout

# %%
# Build the recommendation model using ALS on the training data
# Note we set cold start strategy to 'drop' to ensure we don't get NaN evaluation metrics
# %% [markdown]
# **Part B Q3)**

# %% [markdown]
# **MAE - Mean Absolute Error**<br>
# MAE evaluates the absolute distance of the observations (the entries of the dataset) to the predictions on a regression, taking the average over all observations. We use the absolute value of the distances so that negative errors are accounted properly.<br>
# Formula for MAE - https://miro.medium.com/max/510/1*V5kDRZyG6udD7tKStFotlQ.png<br>
# **MSE - Mean Squared Error**<br>
# MSE squares the distance between the actual and prediction values, taking the average over all observations. Higher errors (or distances) weigh more in the metric than lower ones, due to the nature of the power function. A backlash in MSE is the fact that the unit of the metric is also squared, so if the model tries to predict price in US$, the MSE will yield a number with unit (US$)² which does not make sense.<br>
# Formula for MSE - https://miro.medium.com/max/532/1*VZ3iKUrzH7f71B03Sui6fQ.png<br>
# **RMSE - Root Mean Squared Error**<br>
# RMSE is used to return the MSE error to the original unit by taking the square root of it, while maintaining the property of penalizing higher errors.<br>
# Formula for RMSE -  https://miro.medium.com/max/640/1*YDOgUMYYjETdAVAn7xEOrw.png

# %% [markdown]
# **MAE and RMSE — Which Metric is Better?**  Link - https://medium.com/human-in-a-machine-world/mae-and-rmse-which-metric-is-better-e60ac3bde13d<br>RMSE has the benefit of penalizing large errors more so can be more appropriate in some cases.<br>Thus we prefer RMSE over MAE and MSE

# %%
# Evaluate the model by computing the RMSE on the test data 1
evaluator_1 = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse_1 = evaluator_1.evaluate(predictions_1)
print("Root-mean-square error = " + str(rmse_1))
# Out:
# Root-mean-square error = 1.1427514549626354

# %%
# Evaluate the model by computing the RMSE on the test data 2
evaluator_2 = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse_2 = evaluator_2.evaluate(predictions_2)
print("Root-mean-square error = " + str(rmse_2))
# Out:
# Root-mean-square error = 1.0365173812132722

# %% [markdown]
# Thus, the dataset with train test split of 80-20 is effective and has less errors since a larger part of data (80%) is used for training the model compared to only 60%.

# %% [markdown]
# **Part B Q4)**

# %% [markdown]
# Hyperparameter tuning of model 1

# %%
paramGrid = ParamGridBuilder()\
    .addGrid(als_1.regParam, [0.1, 0.01]) \
    .addGrid(als_1.maxIter, [3,4,5])\
    .addGrid(als_1.alpha, [0.4,0.8])\
    .build()

# %%
crossval_1 = CrossValidator(estimator=als_1,
                           estimatorParamMaps=paramGrid,
                           evaluator=evaluator_1,
                           numFolds=3)

# %%
model_1 = crossval_1.fit(training_1)

# %%
model_1_prediction = model_1.transform(test_1)
rmse_1_tuned = evaluator_1.evaluate(model_1_prediction)
print("Root-mean-square error = " + str(rmse_1_tuned))
# Out:
# Root-mean-square error = 1.2186136086995472

# %%
import numpy as np
print(model_1.getEstimatorParamMaps()[np.argmax(model_1.avgMetrics)])
# Out:
# {Param(parent='ALS_2a02acedeada', name='regParam', doc='regularization parameter (>= 0).'): 0.01, Param(parent='ALS_2a02acedeada', name='maxIter', doc='max number of iterations (>= 0).'): 3, Param(parent='ALS_2a02acedeada', name='alpha', doc='alpha for implicit preference'): 0.4}

# %% [markdown]
# Thus the best parameters for model 1 (60/40 split) are : regParam = 0.01, maxIter = 3 and alpha = 0.4<br>The RMSE of model 1 after tuning is 1.2186

# %% [markdown]
# Hyperparameter tuning of model 2

# %%
crossval_2 = CrossValidator(estimator=als_2,
                           estimatorParamMaps=paramGrid,
                           evaluator=evaluator_2,
                           numFolds=3)

# %%
model_2 = crossval_2.fit(training_2)

# %%
model_2_prediction = model_2.transform(test_2)
rmse_2_tuned = evaluator_2.evaluate(model_2_prediction)
print("Root-mean-square error = " + str(rmse_2_tuned))
# Out:
# Root-mean-square error = 1.0365173812132722

# %%
print(model_2.getEstimatorParamMaps()[np.argmax(model_2.avgMetrics)])
# Out:
# {Param(parent='ALS_2a02acedeada', name='regParam', doc='regularization parameter (>= 0).'): 0.1, Param(parent='ALS_2a02acedeada', name='maxIter', doc='max number of iterations (>= 0).'): 3, Param(parent='ALS_2a02acedeada', name='alpha', doc='alpha for implicit preference'): 0.8}

# %% [markdown]
# Thus the best parameters for model 2 (80/20 split) are regParam = 0.1, maxIter = 4 and alpha = 0.8<br>The RMSE of model 2 after tuning is 1.0365 which is same as before tuning.<br> Hence my recommendation is to not tune the hyper parameters as it just leads to increase in computation time.

# %% [markdown]
# **Comparing the 2 models after Hyper parameter tuning, the best model is model 2 with 80/20 split ratio of RMSE 1.0365**<br>
# More the data used for training, better is the prediction

# %% [markdown]
# **Significance of parameters used for Hyper tuning.**<br>
# **maxIter** is the maximum number of iterations to run (defaults to 10).<br>
# **regParam** specifies the regularization parameter in ALS (defaults to 1.0).<br>
# **alpha** is a parameter applicable to the implicit feedback variant of ALS that governs the baseline confidence in preference observations (defaults to 1.0).

# %% [markdown]
# **Part 2 Q5)**

# %% [markdown]
# Now, extracting the best hyper paramters and using model 2 in ALS, we get

# %%
als = ALS(maxIter=4, regParam=0.1, alpha=0.8, userCol="userId", itemCol="movieId", ratingCol="rating",
          coldStartStrategy="drop")
model = als.fit(training_2)

# %%
predictions = model.transform(test_2)

# %%
userRecs = model.recommendForAllUsers(15)
userRecs.display()
# Out:
# /databricks/spark/python/pyspark/sql/context.py:134: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>recommendations</th></tr></thead><tbody><tr><td>20</td><td>List(List(22, 3.5436418), List(77, 3.1543994), List(88, 2.9691494), List(62, 2.691823), List(51, 2.6850338), List(74, 2.6340606), List(7, 2.4530618), List(98, 2.38503), List(54, 2.3844337), List(94, 2.3465044), List(24, 2.293388), List(32, 2.1524203), List(92, 2.1471808), List(87, 2.1471012), List(41, 2.0527668))</td></tr><tr><td>10</td><td>List(List(49, 2.9692636), List(40, 2.7998114), List(92, 2.5178447), List(42, 2.4445102), List(47, 2.202442), List(4, 2.197721), List(25, 2.1546082), List(0, 2.0897472), List(2, 2.0821645), List(81, 2.0391595), List(85, 1.9937572), List(89, 1.960944), List(1, 1.8860781), List(93, 1.7398272), List(12, 1.7333003))</td></tr><tr><td>0</td><td>List(List(92, 2.8872342), List(62, 2.2493389), List(2, 2.1866317), List(49, 1.9753945), List(89, 1.9657198), List(1, 1.9413546), List(12, 1.9109589), List(4, 1.826584), List(22, 1.8096465), List(77, 1.7510881), List(95, 1.7288542), List(91, 1.7239553), List(41, 1.7123939), List(57, 1.6924877), List(81, 1.6646932))</td></tr><tr><td>1</td><td>List(List(62, 2.7366626), List(77, 2.6835294), List(98, 2.559925), List(29, 2.497772), List(90, 2.429508), List(28, 2.414606), List(85, 2.4139247), List(94, 2.3954282), List(22, 2.3829741), List(52, 2.3825567), List(74, 2.297678), List(51, 2.2233999), List(92, 2.2078123), List(41, 2.1721256), List(88, 2.0996337))</td></tr><tr><td>11</td><td>List(List(27, 4.6242313), List(23, 4.527977), List(32, 4.514224), List(69, 4.504795), List(48, 4.256778), List(18, 4.1610374), List(79, 4.1162205), List(90, 4.075428), List(34, 3.770828), List(66, 3.6660514), List(19, 3.6472616), List(13, 3.576232), List(81, 3.5759928), List(38, 3.4879177), List(30, 3.3979263))</td></tr><tr><td>21</td><td>List(List(29, 4.41662), List(52, 4.207973), List(53, 3.8503525), List(62, 3.808525), List(74, 3.487352), List(76, 3.437942), List(41, 3.073553), List(70, 2.8862903), List(63, 2.8537436), List(85, 2.8116713), List(58, 2.7631187), List(72, 2.720936), List(93, 2.7039273), List(96, 2.5343096), List(67, 2.5243573))</td></tr><tr><td>12</td><td>List(List(27, 4.7341595), List(32, 4.4351935), List(35, 4.3454323), List(17, 4.1923122), List(55, 4.000731), List(48, 3.9757478), List(64, 3.9035752), List(30, 3.903024), List(49, 3.8981318), List(90, 3.8806548), List(46, 3.8727002), List(50, 3.5768325), List(16, 3.539682), List(94, 3.4145155), List(31, 3.0832968))</td></tr><tr><td>2</td><td>List(List(83, 4.499529), List(93, 4.4600716), List(39, 4.053454), List(37, 3.9827049), List(92, 3.8548613), List(40, 3.5830336), List(89, 3.5568874), List(34, 3.492097), List(19, 3.4342837), List(81, 3.2545238), List(4, 3.0386217), List(49, 3.0089474), List(28, 3.001029), List(23, 2.9694078), List(43, 2.9105105))</td></tr><tr><td>22</td><td>List(List(22, 4.464737), List(74, 4.428699), List(88, 4.31415), List(77, 3.6875594), List(32, 3.5696619), List(62, 3.5036075), List(7, 3.460813), List(51, 3.3258634), List(98, 3.2181628), List(54, 3.213729), List(24, 3.1487114), List(41, 3.025909), List(53, 2.9823115), List(29, 2.977372), List(94, 2.963779))</td></tr><tr><td>13</td><td>List(List(74, 2.774088), List(29, 2.5024345), List(41, 2.463862), List(53, 2.4456398), List(52, 2.416337), List(62, 2.4118762), List(93, 2.3580184), List(92, 2.2555149), List(70, 2.1916344), List(28, 2.0996432), List(7, 2.0223842), List(39, 2.006426), List(87, 1.9602845), List(37, 1.9282062), List(83, 1.9176053))</td></tr><tr><td>23</td><td>List(List(32, 4.8268714), List(55, 4.695011), List(90, 4.5592794), List(49, 4.3759985), List(48, 4.2517295), List(27, 4.1733418), List(23, 4.0698647), List(46, 4.062708), List(20, 3.8487244), List(30, 3.8131819), List(17, 3.7686944), List(13, 3.500413), List(35, 3.500189), List(94, 3.4959552), List(50, 3.4611094))</td></tr><tr><td>3</td><td>List(List(51, 4.230642), List(22, 3.7156234),  ...

# %%
import pyspark.sql.functions as f
userRecs.filter(f.col('userId')==10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>recommendations</th></tr></thead><tbody><tr><td>10</td><td>List(List(49, 2.9692636), List(40, 2.7998114), List(92, 2.5178447), List(42, 2.4445102), List(47, 2.202442), List(4, 2.197721), List(25, 2.1546082), List(0, 2.0897472), List(2, 2.0821645), List(81, 2.0391595), List(85, 1.9937572), List(89, 1.960944), List(1, 1.8860781), List(93, 1.7398272), List(12, 1.7333003))</td></tr></tbody></table></div>

# %%
userRecs.filter(f.col('userId')==14).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>recommendations</th></tr></thead><tbody><tr><td>14</td><td>List(List(29, 4.7187376), List(52, 4.655295), List(76, 4.1710854), List(85, 4.0850472), List(62, 3.7639232), List(96, 3.279928), List(63, 3.1719012), List(72, 3.1679373), List(69, 2.9123392), List(53, 2.908828), List(90, 2.886309), List(47, 2.8856504), List(30, 2.8075178), List(58, 2.7764516), List(67, 2.7576265))</td></tr></tbody></table></div>

# %% [markdown]
# There is a chance that the movie recommended to a user is already watched and rated by that user.<br> Hence we need to exclude the movieId already rated by the user in order to get new recommendations.

# %%
userData = df.filter(df.userId.isin([10,14]))
userSubsetRecs = model.recommendForUserSubset(userData, 100)

# %%
newRecommendationsDF = (userSubsetRecs.select('userId',explode('recommendations').alias('recommendation')).select('userId','recommendation.*')).sort('rating',ascending=False)
newRecommendationsDF.select('movieId','rating','userId')
# Out:
# Out[50]: DataFrame[movieId: int, rating: float, userId: int]

# %%
print("Top 15 movies recommended to user 10 are ")
result1 = newRecommendationsDF.join(userData, on =['movieId'],how ='left_anti')
result1.filter(result1.userId.isin([10])).show(15)
# Out:
# Top 15 movies recommended to user 10 are
# +-------+------+----------+
# |movieId|userId|    rating|
# +-------+------+----------+
# |     92|    10| 2.5178447|
# |     81|    10| 2.0391595|
# |     85|    10| 1.9937572|
# |     91|    10| 1.6262096|
# |     87|    10| 1.5756335|
# |     57|    10| 1.5597557|
# |     19|    10| 1.3917103|
# |     33|    10|  1.305766|
# |     61|    10| 1.2916336|
# |     65|    10| 1.1958983|
# |     70|    10| 1.1757578|
# |     23|    10| 0.9971097|
# |     30|    10|0.98390806|
# |     99|    10| 0.9517034|
# |     64|    10| 0.9479872|
# +-------+------+----------+
# only showing top 15 rows

# %%
print("Top 15 movies recommended to user 14 are ")
result2 = newRecommendationsDF.join(userData, on =['movieId'],how ='left_anti')
result2.filter(result2.userId.isin([14])).show(15)
# Out:
# Top 15 movies recommended to user 14 are
# +-------+------+---------+
# |movieId|userId|   rating|
# +-------+------+---------+
# |     85|    14|4.0850472|
# |     30|    14|2.8075178|
# |     59|    14|2.6735032|
# |     70|    14|2.4229238|
# |     74|    14|2.3021817|
# |     87|    14|2.1188734|
# |     61|    14|1.9486207|
# |     60|    14|1.7559137|
# |     92|    14|1.6789422|
# |     91|    14| 1.457192|
# |     32|    14|1.4171797|
# |     81|    14|1.2478681|
# |     26|    14|1.1856362|
# |     46|    14|1.1693587|
# |     33|    14|1.1266334|
# +-------+------+---------+
# only showing top 15 rows
